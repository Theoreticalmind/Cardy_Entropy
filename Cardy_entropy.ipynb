# %% [markdown]
# #This is for t1+t2 fixed and t1 - t2 varying OBC

# %%
using ITensors, ITensorMPS, Plots

function run_dmrg_ssh(N::Int, t1::Float64, t2::Float64, nsweeps::Int, maxdim::Vector{Int}, cutoff::Vector{Float64})
    # Define fermionic sites
    sites = siteinds("Fermion", N)

    # Construct SSH Hamiltonian as an MPO
    os = OpSum()
    for j in 1:N-1
        hopping = j % 2 == 1 ? t1 : t2
        os += -hopping, "Cdag", j, "C", j + 1
        os += -hopping, "Cdag", j + 1, "C", j
    end



    H = MPO(os, sites)

    # Compute the ground state psi0
    state = [isodd(n) ? "1" : "0" for n in 1:N]  # Alternating filling pattern
    psi0_init = randomMPS(sites,state)
    energy_ground, psi_ground = dmrg(H, psi0_init; nsweeps, maxdim, cutoff, noise)

    # Compute the first excited state psi1 
    psi1_init = randomMPS(sites,state)  
    energy_excited, psi_excited = dmrg(H, [psi_ground], psi1_init; nsweeps, maxdim, cutoff, noise, weight=weight)

    # Compute energy gap
    energy_gap = energy_excited - energy_ground

    # Compute entanglement entropy for a subsystem
    function entanglement_entropy(psi, site)
        psi = orthogonalize(psi, site)
        U, S, V = svd(psi[site], (linkinds(psi, site-1)..., siteinds(psi, site)...))
        SvN = 0.0
        for n = 1:dim(S, 1)
            p = S[n, n]^2
            SvN -= p * log(p)
        end
        return SvN
    end

    subsystem_size = div(N, 2)  # Compute entropy at middle site
    entropy = entanglement_entropy(psi_ground, subsystem_size)




    return energy_ground, psi_ground, energy_excited, psi_excited, energy_gap, entropy
end

# Parameters
N = 200           # Number of sites
h = 4.0
weight = 2 
noise = [1E-10]
delta_t_values = collect(-0.2:0.01:0.1)  # Varying delta t from -0.5 to 0.5
nsweeps = 5      # Number of DMRG sweeps
maxdim = [20, 40, 50, 100, 200] 
cutoff = [1E-10] 

# Compute entanglement entropy for different delta t values
entropies = []
for delta_t in delta_t_values
    t1 = 1.0 + delta_t
    t2 = 1.0 - delta_t
    _, _, _, _, _, entropy = run_dmrg_ssh(N, t1, t2, nsweeps, maxdim, cutoff)
    push!(entropies, entropy)
end

# Plot EE vs delta t
plot(delta_t_values, entropies, xlabel="Δt", ylabel="Entanglement Entropy", title="EE vs Δt in SSH Model for N= 200 sites", marker=:o)
savefig("EE_vs_delta_t.png")
# Out:
# After sweep 1 energy=-132.59341468665875  maxlinkdim=4 maxerr=4.91E-11 time=0.218
# After sweep 2 energy=-132.83849139101576  maxlinkdim=15 maxerr=9.12E-11 time=0.235
# After sweep 3 energy=-132.83884429860743  maxlinkdim=29 maxerr=9.99E-11 time=0.477
# After sweep 4 energy=-132.83884479966616  maxlinkdim=28 maxerr=9.97E-11 time=0.581
# After sweep 5 energy=-132.8388447994841  maxlinkdim=27 maxerr=9.98E-11 time=0.557
# After sweep 1 energy=-131.22034266595617  maxlinkdim=4 maxerr=5.89E-11 time=0.201
# After sweep 2 energy=-132.83396143368861  maxlinkdim=16 maxerr=9.98E-11 time=0.276
# After sweep 3 energy=-132.83884281032454  maxlinkdim=29 maxerr=9.98E-11 time=0.527
# After sweep 4 energy=-132.83884479489376  maxlinkdim=28 maxerr=1.00E-10 time=0.664
# After sweep 5 energy=-132.83884479177297  maxlinkdim=27 maxerr=1.00E-10 time=0.889
# After sweep 1 energy=-132.07735220042613  maxlinkdim=4 maxerr=4.90E-11 time=0.180
# After sweep 2 energy=-132.34487230586907  maxlinkdim=15 maxerr=8.16E-11 time=0.246
# After sweep 3 energy=-132.3453070353445  maxlinkdim=30 maxerr=1.00E-10 time=0.440
# After sweep 4 energy=-132.34530768690323  maxlinkdim=29 maxerr=9.99E-11 time=0.554
# After sweep 5 energy=-132.34530768709033  maxlinkdim=29 maxerr=1.00E-10 time=0.549
# After sweep 1 energy=-130.74151840188338  maxlinkdim=4 maxerr=5.71E-11 time=0.198
# After sweep 2 energy=-132.3404882357046  maxlinkdim=16 maxerr=9.22E-11 time=0.270
# After sweep 3 energy=-132.3453053383048  maxlinkdim=30 maxerr=9.96E-11 time=0.535
# After sweep 4 energy=-132.34530768091795  maxlinkdim=29 maxerr=9.98E-11 time=0.687
# After sweep 5 energy=-132.34530768732023  maxlinkdim=29 maxerr=1.00E-10 time=0.928
# After sweep 1 energy=-131.57449895112288  maxlinkdim=4 maxerr=4.89E-11 time=0.173
# After sweep 2 energy=-131.8664703359354  maxlinkdim=15 maxerr=9.99E-11 time=0.241
# After sweep 3 energy=-131.86700798268447  maxlinkdim=31 maxerr=9.95E-11 time=0.448
# After sweep 4 energy=-131.8670088884007  maxlinkdim=31 maxerr=9.97E-11 time=0.596
# After sweep 5 energy=-131.86700888882808  maxlinkdim=30 maxerr=9.96E-11 time=0.587
# After sweep 1 energy=-130.27538758631073  maxlinkdim=4 maxerr=5.56E-11 time=0.208
# After sweep 2 energy=-131.85992463316487  maxlinkdim=16 maxerr=9.22E-11 time=0.271
# After sweep 3 energy=-131.8670054207377  maxlinkdim=31 maxerr=9.99E-11 time=0.537
# After sweep 4 energy=-131.8670088817705  maxlinkdim=30 maxerr=9.92E-11 time=0.929
# After sweep 5 energy=-131.8670088887348  maxlinkdim=30 maxerr=9.96E-11 time=0.600
# After sweep 1 energy=-131.0852885485534  maxlinkdim=4 maxerr=4.87E-11 time=0.166
# After sweep 2 energy=-131.40388005468014  maxlinkdim=15 maxerr=9.72E-11 time=0.220
# After sweep 3 energy=-131.40454705034844  maxlinkdim=32 maxerr=9.95E-11 time=0.474
# After sweep 4 energy=-131.40454756124026  maxlinkdim=32 maxerr=9.97E-11 time=0.605
# After sweep 5 energy=-131.40454756107306  maxlinkdim=32 maxerr=9.98E-11 time=0.614
# After sweep 1 energy=-129.82442847131264  maxlinkdim=4 maxerr=5.48E-11 time=0.203
# After sweep 2 energy=-131.35957751833496  maxlinkdim=16 maxerr=8.25E-11 time=0.281
# After sweep 3 energy=-131.40453190436017  maxlinkdim=32 maxerr=9.98E-11 time=0.566
# After sweep 4 energy=-131.40454751172425  maxlinkdim=34 maxerr=1.00E-10 time=0.988
# After sweep 5 energy=-131.40454756117202  maxlinkdim=32 maxerr=9.98E-11 time=0.694
# After sweep 1 energy=-130.61019536167882  maxlinkdim=4 maxerr=4.86E-11 time=0.158
# After sweep 2 energy=-130.9577361589455  maxlinkdim=15 maxerr=9.87E-11 time=0.235
# After sweep 3 energy=-130.9585655197859  maxlinkdim=32 maxerr=9.95E-11 time=0.512
# After sweep 4 energy=-130.95856631425585  maxlinkdim=34 maxerr=9.97E-11 time=0.676
# After sweep 5 energy=-130.95856631467475  maxlinkdim=33 maxerr=9.99E-11 time=0.693
# After sweep 1 energy=-129.39433240740658  maxlinkdim=4 maxerr=5.48E-11 time=0.219
# After sweep 2 energy=-130.94422107620832  maxlinkdim=16 maxerr=9.72E-11 time=0.294
# After sweep 3 energy=-130.958555403668  maxlinkdim=34 maxerr=1.00E-10 time=0.880
# After sweep 4 energy=-130.95856627117365  maxlinkdim=35 maxerr=9.97E-11 time=0.751
# After sweep 5 energy=-130.95856631502858  maxlinkdim=33 maxerr=9.85E-11 time=0.833
# After sweep 1 energy=-130.14974585412455  maxlinkdim=4 maxerr=4.84E-11 time=0.167
# After sweep 2 energy=-130.52872042068137  maxlinkdim=16 maxerr=9.47E-11 time=0.234
# After sweep 3 energy=-130.52975536197317  maxlinkdim=33 maxerr=9.92E-11 time=0.561
# After sweep 4 energy=-130.5297565496005  maxlinkdim=36 maxerr=1.00E-10 time=0.772
# After sweep 5 energy=-130.52975655125937  maxlinkdim=34 maxerr=9.97E-11 time=0.998
# After sweep 1 energy=-128.97746002341017  maxlinkdim=4 maxerr=5.48E-11 time=0.218
# After sweep 2 energy=-130.51688482996423  maxlinkdim=16 maxerr=9.99E-11 time=0.292
# After sweep 3 energy=-130.52974602597695  maxlinkdim=34 maxerr=9.99E-11 time=0.602
# After sweep 4 energy=-130.5297564934258  maxlinkdim=36 maxerr=9.99E-11 time=0.850
# After sweep 5 energy=-130.52975655169038  maxlinkdim=34 maxerr=9.96E-11 time=0.913
# After sweep 1 energy=-129.7045342463931  maxlinkdim=4 maxerr=4.81E-11 time=0.174
# After sweep 2 energy=-130.1175592076069  maxlinkdim=16 maxerr=9.71E-11 time=0.226
# After sweep 3 energy=-130.11886358417703  maxlinkdim=34 maxerr=9.98E-11 time=0.768
# After sweep 4 energy=-130.11886496580067  maxlinkdim=37 maxerr=9.99E-11 time=0.788
# After sweep 5 energy=-130.11886496692748  maxlinkdim=36 maxerr=9.99E-11 time=0.868
# After sweep 1 energy=-128.57153273748915  maxlinkdim=4 maxerr=4.85E-11 time=0.215
# After sweep 2 energy=-130.11428869604472  maxlinkdim=16 maxerr=9.88E-11 time=0.274
# After sweep 3 energy=-130.1188548603371  maxlinkdim=34 maxerr=1.00E-10 time=0.634
# After sweep 4 energy=-130.11886491245477  maxlinkdim=37 maxerr=9.99E-11 time=1.124
# After sweep 5 energy=-130.118864967912  maxlinkdim=36 maxerr=9.99E-11 time=0.994
# After sweep 1 energy=-129.27524424851038  maxlinkdim=4 maxerr=4.79E-11 time=0.161
# After sweep 2 energy=-129.72506254179012  maxlinkdim=16 maxerr=9.76E-11 time=0.228
# After sweep 3 energy=-129.72669942298285  maxlinkdim=35 maxerr=9.97E-11 time=0.554
# After sweep 4 energy=-129.7267014534802  maxlinkdim=39 maxerr=9.99E-11 time=1.120
# After sweep 5 energy=-129.72670145830358  maxlinkdim=38 maxerr=9.96E-11 time=0.924
# After sweep 1 energy=-128.20307597043052  maxlinkdim=4 maxerr=4.55E-11 time=0.216
# After sweep 2 energy=-129.441492130025  maxlinkdim=16 maxerr=6.55E-11 time=0.281
# After sweep 3 energy=-129.72530257308844  maxlinkdim=45 maxerr=9.97E-11 time=0.795
# After sweep 4 energy=-129.72670069626494  maxlinkdim=49 maxerr=1.00E-10 time=1.385
# After sweep 5 energy=-129.7267014585336  maxlinkdim=38 maxerr=9.93E-11 time=1.071
# After sweep 1 energy=-128.86267929132214  maxlinkdim=4 maxerr=4.76E-11 time=0.194
# After sweep 2 energy=-129.3520768015351  maxlinkdim=16 maxerr=9.37E-11 time=0.225
# After sweep 3 energy=-129.35414576779684  maxlinkdim=38 maxerr=9.85E-11 time=0.612
# After sweep 4 energy=-129.3541487074335  maxlinkdim=40 maxerr=9.86E-11 time=0.995
# After sweep 5 energy=-129.35414871531245  maxlinkdim=40 maxerr=9.99E-11 time=1.237
# After sweep 1 energy=-127.86179753862139  maxlinkdim=4 maxerr=4.55E-11 time=0.216
# After sweep 2 energy=-129.2963872091485  maxlinkdim=16 maxerr=9.11E-11 time=0.282
# After sweep 3 energy=-129.35400266378855  maxlinkdim=40 maxerr=9.95E-11 time=0.709
# After sweep 4 energy=-129.35414786203899  maxlinkdim=43 maxerr=9.98E-11 time=1.134
# After sweep 5 energy=-129.35414871593804  maxlinkdim=40 maxerr=9.99E-11 time=1.410
# After sweep 1 energy=-128.46780458093232  maxlinkdim=4 maxerr=4.72E-11 time=0.168
# After sweep 2 energy=-128.99953882049806  maxlinkdim=16 maxerr=9.69E-11 time=0.229
# After sweep 3 energy=-129.0021694441818  maxlinkdim=38 maxerr=9.92E-11 time=0.618
# After sweep 4 energy=-129.0021742492918  maxlinkdim=43 maxerr=1.00E-10 time=1.021
# After sweep 5 energy=-129.0021742683838  maxlinkdim=41 maxerr=9.97E-11 time=1.297
# After sweep 1 energy=-127.54641785458968  maxlinkdim=4 maxerr=4.56E-11 time=0.215
# After sweep 2 energy=-128.89124006159395  maxlinkdim=16 maxerr=7.09E-11 time=0.283
# After sweep 3 energy=-129.00196947360067  maxlinkdim=42 maxerr=1.00E-10 time=0.726
# After sweep 4 energy=-129.00217378488313  maxlinkdim=43 maxerr=9.99E-11 time=1.262
# After sweep 5 energy=-129.00217426904427  maxlinkdim=42 maxerr=9.96E-11 time=1.429
# After sweep 1 energy=-128.0918053832315  maxlinkdim=4 maxerr=4.68E-11 time=0.165
# After sweep 2 energy=-128.66847002710387  maxlinkdim=16 maxerr=9.11E-11 time=0.233
# After sweep 3 energy=-128.6718380542417  maxlinkdim=39 maxerr=9.98E-11 time=0.638
# After sweep 4 energy=-128.6718457613631  maxlinkdim=46 maxerr=9.98E-11 time=1.368
# After sweep 5 energy=-128.67184578543876  maxlinkdim=44 maxerr=9.98E-11 time=1.143
# After sweep 1 energy=-127.25722164666047  maxlinkdim=4 maxerr=4.55E-11 time=0.217
# After sweep 2 energy=-128.65224262527886  maxlinkdim=16 maxerr=6.81E-11 time=0.281
# After sweep 3 energy=-128.67175901550937  maxlinkdim=39 maxerr=9.98E-11 time=0.758
# After sweep 4 energy=-128.6718450146166  maxlinkdim=49 maxerr=9.99E-11 time=1.491
# After sweep 5 energy=-128.6718457903705  maxlinkdim=46 maxerr=1.00E-10 time=1.384
# After sweep 1 energy=-127.73616702452864  maxlinkdim=4 maxerr=4.63E-11 time=0.168
# After sweep 2 energy=-128.35999235419203  maxlinkdim=16 maxerr=6.77E-11 time=0.227
# After sweep 3 energy=-128.36433840899548  maxlinkdim=41 maxerr=9.98E-11 time=0.715
# After sweep 4 energy=-128.36435077809264  maxlinkdim=49 maxerr=1.00E-10 time=1.353
# After sweep 5 energy=-128.36435081370382  maxlinkdim=48 maxerr=1.00E-10 time=1.313
# After sweep 1 energy=-126.99465735331734  maxlinkdim=4 maxerr=4.49E-11 time=0.223
# After sweep 2 energy=-128.33380785665238  maxlinkdim=16 maxerr=6.00E-11 time=0.283
# After sweep 3 energy=-128.3641742364856  maxlinkdim=41 maxerr=1.00E-10 time=0.954
# After sweep 4 energy=-128.36434764318182  maxlinkdim=49 maxerr=9.99E-11 time=1.258
# After sweep 5 energy=-128.36435081077576  maxlinkdim=51 maxerr=1.00E-10 time=1.682
# After sweep 1 energy=-127.40278256980079  maxlinkdim=4 maxerr=4.57E-11 time=0.170
# After sweep 2 energy=-128.0753448455691  maxlinkdim=16 maxerr=9.04E-11 time=0.224
# After sweep 3 energy=-128.08100315206323  maxlinkdim=41 maxerr=1.00E-10 time=0.678
# After sweep 4 energy=-128.08102297058142  maxlinkdim=52 maxerr=9.99E-11 time=1.563
# After sweep 5 energy=-128.08102308249906  maxlinkdim=52 maxerr=1.00E-10 time=1.344
# After sweep 1 energy=-126.75869927412549  maxlinkdim=4 maxerr=4.45E-11 time=0.213
# After sweep 2 energy=-127.88416400736149  maxlinkdim=16 maxerr=9.96E-11 time=0.299
# After sweep 3 energy=-128.07636444857758  maxlinkdim=50 maxerr=1.00E-10 time=0.849
# After sweep 4 energy=-128.08099096553804  maxlinkdim=58 maxerr=1.00E-10 time=1.706
# After sweep 5 energy=-128.08102301793664  maxlinkdim=57 maxerr=1.00E-10 time=1.873
# After sweep 1 energy=-127.09409249591859  maxlinkdim=4 maxerr=4.51E-11 time=0.226
# After sweep 2 energy=-127.81590469595422  maxlinkdim=16 maxerr=9.42E-11 time=0.233
# After sweep 3 energy=-127.82334104062338  maxlinkdim=43 maxerr=9.99E-11 time=0.688
# After sweep 4 energy=-127.82337826050627  maxlinkdim=57 maxerr=9.98E-11 time=1.423
# After sweep 5 energy=-127.82337870907594  maxlinkdim=58 maxerr=1.00E-10 time=1.928
# After sweep 1 energy=-126.54926716354142  maxlinkdim=4 maxerr=4.43E-11 time=0.217
# After sweep 2 energy=-127.65423088234306  maxlinkdim=16 maxerr=8.94E-11 time=0.288
# After sweep 3 energy=-127.81902716276774  maxlinkdim=50 maxerr=9.98E-11 time=0.855
# After sweep 4 energy=-127.82331404304055  maxlinkdim=55 maxerr=1.00E-10 time=1.768
# After sweep 5 energy=-127.82337829392097  maxlinkdim=61 maxerr=9.99E-11 time=2.118
# After sweep 1 energy=-126.81325359385055  maxlinkdim=4 maxerr=4.43E-11 time=0.170
# After sweep 2 energy=-127.58321464851235  maxlinkdim=16 maxerr=8.48E-11 time=0.227
# After sweep 3 energy=-127.59310295942963  maxlinkdim=45 maxerr=9.98E-11 time=0.765
# After sweep 4 energy=-127.59316652566126  maxlinkdim=61 maxerr=1.00E-10 time=1.830
# After sweep 5 energy=-127.59316763425144  maxlinkdim=64 maxerr=1.00E-10 time=2.025
# After sweep 1 energy=-126.36589208946432  maxlinkdim=4 maxerr=4.40E-11 time=0.279
# After sweep 2 energy=-127.42225997128506  maxlinkdim=16 maxerr=9.97E-11 time=0.530
# After sweep 3 energy=-127.58072909597686  maxlinkdim=50 maxerr=2.93E-10 time=0.885
# After sweep 4 energy=-127.59288212609526  maxlinkdim=64 maxerr=9.99E-11 time=2.005
# After sweep 5 energy=-127.59316617356318  maxlinkdim=66 maxerr=1.00E-10 time=2.152
# After sweep 1 energy=-126.56431562525647  maxlinkdim=4 maxerr=4.36E-11 time=0.182
# After sweep 2 energy=-127.37902324574029  maxlinkdim=16 maxerr=8.76E-11 time=0.227
# After sweep 3 energy=-127.39230793481761  maxlinkdim=47 maxerr=9.93E-11 time=1.008
# After sweep 4 energy=-127.3924459874068  maxlinkdim=66 maxerr=9.99E-11 time=1.723
# After sweep 5 energy=-127.39245078489857  maxlinkdim=74 maxerr=1.00E-10 time=2.560
# After sweep 1 energy=-126.20813952875956  maxlinkdim=4 maxerr=4.36E-11 time=0.220
# After sweep 2 energy=-127.18617259092889  maxlinkdim=16 maxerr=9.77E-11 time=0.311
# After sweep 3 energy=-127.3518403136917  maxlinkdim=50 maxerr=1.59E-09 time=1.159
# After sweep 4 energy=-127.38984312874422  maxlinkdim=70 maxerr=9.98E-11 time=1.605
# After sweep 5 energy=-127.39240574546821  maxlinkdim=70 maxerr=9.99E-11 time=2.315
# After sweep 1 energy=-126.35234526288197  maxlinkdim=4 maxerr=4.33E-11 time=0.172
# After sweep 2 energy=-127.20536073807529  maxlinkdim=16 maxerr=9.04E-11 time=0.225
# After sweep 3 energy=-127.22333881449867  maxlinkdim=49 maxerr=9.98E-11 time=1.029
# After sweep 4 energy=-127.22370414564101  maxlinkdim=68 maxerr=9.99E-11 time=1.796
# After sweep 5 energy=-127.22372328287166  maxlinkdim=84 maxerr=9.99E-11 time=2.755
# After sweep 1 energy=-126.07652508851277  maxlinkdim=4 maxerr=4.33E-11 time=0.279
# After sweep 2 energy=-127.11835902755843  maxlinkdim=16 maxerr=4.68E-11 time=0.542
# After sweep 3 energy=-127.21761399633594  maxlinkdim=47 maxerr=9.96E-11 time=0.925
# After sweep 4 energy=-127.22326389410793  maxlinkdim=61 maxerr=9.98E-11 time=2.072
# After sweep 5 energy=-127.22369707968875  maxlinkdim=75 maxerr=1.00E-10 time=2.322
# After sweep 1 energy=-126.1833736386892  maxlinkdim=4 maxerr=4.29E-11 time=0.171
# After sweep 2 energy=-127.0647413624124  maxlinkdim=16 maxerr=9.54E-11 time=0.222
# After sweep 3 energy=-127.08938616816414  maxlinkdim=50 maxerr=9.97E-11 time=1.021
# After sweep 4 energy=-127.09006659198965  maxlinkdim=71 maxerr=1.00E-10 time=2.279
# After sweep 5 energy=-127.09013252874587  maxlinkdim=85 maxerr=1.00E-10 time=2.963
# After sweep 1 energy=-125.97315760911555  maxlinkdim=4 maxerr=4.29E-11 time=0.256
# After sweep 2 energy=-126.96365027691388  maxlinkdim=16 maxerr=8.84E-11 time=0.334
# After sweep 3 energy=-127.07968325986411  maxlinkdim=50 maxerr=1.13E-10 time=1.103
# After sweep 4 energy=-127.08882496711207  maxlinkdim=63 maxerr=1.00E-10 time=2.522
# After sweep 5 energy=-127.09000880875631  maxlinkdim=75 maxerr=1.00E-10 time=2.664
# After sweep 1 energy=-126.06398061673872  maxlinkdim=4 maxerr=4.25E-11 time=0.173
# After sweep 2 energy=-126.9608663710504  maxlinkdim=16 maxerr=6.36E-11 time=0.228
# After sweep 3 energy=-126.99401396012804  maxlinkdim=50 maxerr=9.99E-11 time=0.840
# After sweep 4 energy=-126.99567572573764  maxlinkdim=75 maxerr=9.99E-11 time=2.224
# After sweep 5 energy=-126.99596535715402  maxlinkdim=92 maxerr=9.99E-11 time=3.184
# After sweep 1 energy=-125.90186589579753  maxlinkdim=4 maxerr=4.25E-11 time=0.290
# After sweep 2 energy=-126.8900905478792  maxlinkdim=16 maxerr=7.94E-11 time=0.544
# After sweep 3 energy=-126.97463791938625  maxlinkdim=50 maxerr=1.76E-10 time=1.040
# After sweep 4 energy=-126.98967379648558  maxlinkdim=81 maxerr=1.00E-10 time=2.924
# After sweep 5 energy=-126.99475596359912  maxlinkdim=102 maxerr=1.00E-10 time=3.844
# After sweep 1 energy=-126.00035347288744  maxlinkdim=4 maxerr=4.21E-11 time=0.188
# After sweep 2 energy=-126.90124638074187  maxlinkdim=16 maxerr=4.56E-11 time=0.223
# After sweep 3 energy=-126.94315714947264  maxlinkdim=50 maxerr=1.37E-10 time=1.015
# After sweep 4 energy=-126.94671205536714  maxlinkdim=72 maxerr=1.00E-10 time=2.319
# After sweep 5 energy=-126.94817337493052  maxlinkdim=100 maxerr=1.00E-10 time=3.236
# After sweep 1 energy=-125.86880859788131  maxlinkdim=4 maxerr=4.21E-11 time=0.235
# After sweep 2 energy=-126.83646229269341  maxlinkdim=16 maxerr=4.25E-11 time=0.323
# After sweep 3 energy=-126.92028989196868  maxlinkdim=50 maxerr=4.28E-10 time=1.361
# After sweep 4 energy=-126.93573883357061  maxlinkdim=80 maxerr=9.99E-11 time=2.903
# After sweep 5 energy=-126.94274170711621  maxlinkdim=100 maxerr=1.00E-10 time=3.908
# After sweep 1 energy=-125.9969003894722  maxlinkdim=4 maxerr=4.17E-11 time=0.175
# After sweep 2 energy=-126.90251378581799  maxlinkdim=16 maxerr=6.76E-11 time=0.237
# After sweep 3 energy=-126.95115116120058  maxlinkdim=50 maxerr=1.55E-10 time=0.907
# After sweep 4 energy=-126.9570754486634  maxlinkdim=80 maxerr=1.00E-10 time=2.324
# After sweep 5 energy=-126.96005146747797  maxlinkdim=112 maxerr=1.00E-10 time=3.316
# After sweep 1 energy=-125.90542883038263  maxlinkdim=4 maxerr=4.17E-11 time=0.296
# After sweep 2 energy=-126.84224076657138  maxlinkdim=16 maxerr=4.15E-11 time=0.582
# After sweep 3 energy=-126.9280780932719  maxlinkdim=50 maxerr=2.61E-10 time=1.014
# After sweep 4 energy=-126.94032139202186  maxlinkdim=82 maxerr=1.00E-10 time=2.913
# After sweep 5 energy=-126.94443012874574  maxlinkdim=108 maxerr=1.00E-10 time=4.047
# After sweep 1 energy=-126.05493705079834  maxlinkdim=4 maxerr=4.12E-11 time=0.165
# After sweep 2 energy=-126.97374998474142  maxlinkdim=16 maxerr=8.39E-11 time=0.234
# After sweep 3 energy=-127.01936341098343  maxlinkdim=50 maxerr=1.53E-10 time=1.042
# After sweep 4 energy=-127.02321218530943  maxlinkdim=80 maxerr=1.00E-10 time=2.389
# After sweep 5 energy=-127.02379611250593  maxlinkdim=99 maxerr=1.00E-10 time=3.857
# After sweep 1 energy=-125.96570889150377  maxlinkdim=4 maxerr=4.12E-11 time=0.249
# After sweep 2 energy=-126.85788858695221  maxlinkdim=16 maxerr=4.02E-11 time=0.343
# After sweep 3 energy=-126.96904311424778  maxlinkdim=50 maxerr=2.08E-10 time=1.418
# After sweep 4 energy=-126.98209919762158  maxlinkdim=79 maxerr=1.00E-10 time=2.745
# After sweep 5 energy=-126.98838971302813  maxlinkdim=102 maxerr=1.00E-10 time=3.630
# After sweep 1 energy=-126.17219767987143  maxlinkdim=4 maxerr=4.07E-11 time=0.179
# After sweep 2 energy=-127.09478346991298  maxlinkdim=16 maxerr=9.88E-11 time=0.229
# After sweep 3 energy=-127.12943001942334  maxlinkdim=50 maxerr=9.98E-11 time=0.829
# After sweep 4 energy=-127.13072835468942  maxlinkdim=73 maxerr=1.00E-10 time=2.170
# After sweep 5 energy=-127.13085037045045  maxlinkdim=93 maxerr=1.00E-10 time=3.129
# After sweep 1 energy=-126.049490404511  maxlinkdim=4 maxerr=4.07E-11 time=0.290
# After sweep 2 energy=-126.95565148551356  maxlinkdim=16 maxerr=3.91E-11 time=0.572
# After sweep 3 energy=-127.06000391154629  maxlinkdim=50 maxerr=1.68E-10 time=1.029
# After sweep 4 energy=-127.07126715109752  maxlinkdim=74 maxerr=1.00E-10 time=2.658
# After sweep 5 energy=-127.07673184823727  maxlinkdim=99 maxerr=1.00E-10 time=3.577
# After sweep 1 energy=-126.34351082790046  maxlinkdim=4 maxerr=4.03E-11 time=0.175
# After sweep 2 energy=-127.251781452813  maxlinkdim=16 maxerr=7.53E-11 time=0.227
# After sweep 3 energy=-127.27640664343755  maxlinkdim=45 maxerr=9.76E-11 time=0.771
# After sweep 4 energy=-127.27703257775819  maxlinkdim=61 maxerr=9.98E-11 time=1.996
# After sweep 5 energy=-127.27706152063001  maxlinkdim=83 maxerr=1.00E-10 time=2.922
# After sweep 1 energy=-126.1698126217885  maxlinkdim=4 maxerr=4.03E-11 time=0.235
# After sweep 2 energy=-127.0630518153432  maxlinkdim=16 maxerr=9.31E-11 time=0.312
# After sweep 3 energy=-127.17735386594924  maxlinkdim=50 maxerr=1.18E-10 time=1.172
# After sweep 4 energy=-127.19076862239183  maxlinkdim=69 maxerr=9.99E-11 time=2.212
# After sweep 5 energy=-127.19819125176328  maxlinkdim=88 maxerr=9.99E-11 time=2.453
# After sweep 1 energy=-126.56220998992879  maxlinkdim=4 maxerr=3.97E-11 time=0.473
# After sweep 2 energy=-127.44041551573068  maxlinkdim=16 maxerr=8.55E-11 time=0.224
# After sweep 3 energy=-127.45802553321323  maxlinkdim=45 maxerr=9.95E-11 time=0.697
# After sweep 4 energy=-127.45832744319475  maxlinkdim=58 maxerr=9.99E-11 time=1.604
# After sweep 5 energy=-127.45833697347328  maxlinkdim=74 maxerr=9.98E-11 time=2.580
# After sweep 1 energy=-126.32088261109382  maxlinkdim=4 maxerr=3.97E-11 time=0.221
# After sweep 2 energy=-127.22917884261246  maxlinkdim=16 maxerr=4.95E-11 time=0.580
# After sweep 3 energy=-127.34557732824074  maxlinkdim=50 maxerr=9.97E-11 time=0.916
# After sweep 4 energy=-127.35516603046969  maxlinkdim=71 maxerr=1.00E-10 time=2.234
# After sweep 5 energy=-127.36131289686807  maxlinkdim=92 maxerr=9.99E-11 time=2.492
# After sweep 1 energy=-126.82151070345489  maxlinkdim=4 maxerr=3.92E-11 time=0.228
# After sweep 2 energy=-127.65860437426278  maxlinkdim=16 maxerr=4.78E-11 time=0.474
# After sweep 3 energy=-127.67145169931982  maxlinkdim=44 maxerr=9.91E-11 time=0.688
# After sweep 4 energy=-127.67155263417014  maxlinkdim=59 maxerr=1.00E-10 time=1.601
# After sweep 5 energy=-127.67155409430485  maxlinkdim=64 maxerr=1.00E-10 time=2.369
# After sweep 1 energy=-126.49802410888175  maxlinkdim=4 maxerr=3.92E-11 time=0.228
# After sweep 2 energy=-127.42550653931615  maxlinkdim=16 maxerr=3.45E-11 time=0.306
# After sweep 3 energy=-127.5551222492214  maxlinkdim=50 maxerr=1.71E-10 time=1.199
# After sweep 4 energy=-127.56018913115639  maxlinkdim=67 maxerr=1.00E-10 time=2.306
# After sweep 5 energy=-127.56251774931167  maxlinkdim=92 maxerr=1.00E-10 time=2.461
# After sweep 1 energy=-127.11538075420626  maxlinkdim=4 maxerr=3.87E-11 time=0.164
# After sweep 2 energy=-127.90468915442979  maxlinkdim=16 maxerr=3.52E-11 time=0.236
# After sweep 3 energy=-127.91417547490893  maxlinkdim=43 maxerr=9.98E-11 time=0.910
# After sweep 4 energy=-127.91422154452121  maxlinkdim=55 maxerr=1.00E-10 time=1.401
# After sweep 5 energy=-127.91422189485701  maxlinkdim=57 maxerr=9.98E-11 time=1.963
# After sweep 1 energy=-126.69899910130565  maxlinkdim=4 maxerr=3.87E-11 time=0.214
# After sweep 2 energy=-127.60608152927112  maxlinkdim=16 maxerr=3.43E-11 time=0.299
# After sweep 3 energy=-127.78026863618479  maxlinkdim=50 maxerr=1.60E-10 time=0.964
# After sweep 4 energy=-127.78546632932459  maxlinkdim=67 maxerr=9.99E-11 time=2.064
# After sweep 5 energy=-127.7875869392474  maxlinkdim=88 maxerr=1.00E-10 time=2.699
# After sweep 1 energy=-127.43887465997953  maxlinkdim=4 maxerr=3.81E-11 time=0.166
# After sweep 2 energy=-128.17714739668457  maxlinkdim=16 maxerr=9.23E-11 time=0.235
# After sweep 3 energy=-128.1842488863747  maxlinkdim=41 maxerr=9.79E-11 time=0.707
# After sweep 4 energy=-128.18427910673674  maxlinkdim=51 maxerr=1.00E-10 time=1.564
# After sweep 5 energy=-128.18427928448094  maxlinkdim=50 maxerr=9.99E-11 time=1.506
# After sweep 1 energy=-126.92356966441477  maxlinkdim=4 maxerr=3.81E-11 time=0.210
# After sweep 2 energy=-127.87473045650297  maxlinkdim=16 maxerr=8.28E-11 time=0.294
# After sweep 3 energy=-128.0310632984175  maxlinkdim=50 maxerr=1.20E-10 time=1.085
# After sweep 4 energy=-128.0350026370773  maxlinkdim=69 maxerr=9.98E-11 time=1.674
# After sweep 5 energy=-128.03690767634464  maxlinkdim=87 maxerr=1.00E-10 time=2.457
# After sweep 1 energy=-127.78812224818526  maxlinkdim=4 maxerr=3.76E-11 time=0.175
# After sweep 2 energy=-128.47456515864147  maxlinkdim=16 maxerr=7.05E-11 time=0.223
# After sweep 3 energy=-128.47995829094424  maxlinkdim=39 maxerr=9.99E-11 time=0.653
# After sweep 4 energy=-128.47997464356635  maxlinkdim=46 maxerr=1.00E-10 time=1.379
# After sweep 5 energy=-128.47997468645565  maxlinkdim=45 maxerr=1.00E-10 time=1.229
# After sweep 1 energy=-127.17266288149337  maxlinkdim=4 maxerr=3.76E-11 time=0.207
# After sweep 2 energy=-128.23136763599607  maxlinkdim=16 maxerr=5.12E-11 time=0.286
# After sweep 3 energy=-128.29452423062992  maxlinkdim=50 maxerr=1.08E-10 time=1.049
# After sweep 4 energy=-128.30231660913395  maxlinkdim=69 maxerr=9.99E-11 time=1.415
# After sweep 5 energy=-128.306746214281  maxlinkdim=63 maxerr=1.00E-10 time=1.859
# After sweep 1 energy=-128.16016372031314  maxlinkdim=4 maxerr=3.70E-11 time=0.163
# After sweep 2 energy=-128.7956386707384  maxlinkdim=16 maxerr=7.80E-11 time=0.230
# After sweep 3 energy=-128.79977932126457  maxlinkdim=37 maxerr=9.92E-11 time=0.642
# After sweep 4 energy=-128.79978986284218  maxlinkdim=42 maxerr=9.98E-11 time=1.070
# After sweep 5 energy=-128.79978988870323  maxlinkdim=43 maxerr=9.98E-11 time=1.379
# After sweep 1 energy=-127.44750827649243  maxlinkdim=4 maxerr=3.70E-11 time=0.218
# After sweep 2 energy=-128.28838513222732  maxlinkdim=16 maxerr=6.31E-11 time=0.281
# After sweep 3 energy=-128.5714723460486  maxlinkdim=46 maxerr=9.99E-11 time=0.821
# After sweep 4 energy=-128.58954131129764  maxlinkdim=52 maxerr=9.97E-11 time=1.520
# After sweep 5 energy=-128.59759870478157  maxlinkdim=59 maxerr=1.00E-10 time=1.381
# After sweep 1 energy=-128.55275035481438  maxlinkdim=4 maxerr=3.64E-11 time=0.170
# After sweep 2 energy=-129.13917160916196  maxlinkdim=16 maxerr=8.49E-11 time=0.220
# After sweep 3 energy=-129.14238243378028  maxlinkdim=35 maxerr=9.98E-11 time=0.602
# After sweep 4 energy=-129.1423889384366  maxlinkdim=41 maxerr=9.95E-11 time=1.249
# After sweep 5 energy=-129.142388950972  maxlinkdim=41 maxerr=9.99E-11 time=1.040
# After sweep 1 energy=-127.74893084317986  maxlinkdim=4 maxerr=3.64E-11 time=0.205
# After sweep 2 energy=-128.60559125197906  maxlinkdim=16 maxerr=8.36E-11 time=0.289
# After sweep 3 energy=-128.8961503361477  maxlinkdim=49 maxerr=9.99E-11 time=0.793
# After sweep 4 energy=-128.91045127247108  maxlinkdim=62 maxerr=9.99E-11 time=1.503
# After sweep 5 energy=-128.91998773949248  maxlinkdim=71 maxerr=9.99E-11 time=1.408
# "/home/photon/Downloads/Cardy_Entropy/EE_vs_delta_t.png"

# %% [markdown]
# #This is for S(l)=C/6 log((L\pi)sin(pi.l/L))

# %%
using ITensors, ITensorMPS, Plots, LsqFit

function run_dmrg_ssh(N::Int, t1::Float64, t2::Float64, nsweeps::Int, maxdim::Vector{Int}, cutoff::Vector{Float64})
    # Define fermionic sites
    sites = siteinds("Fermion", N)

    # Construct SSH Hamiltonian as an MPO
    os = OpSum()
    for j in 1:N-1
        hopping = j % 2 == 1 ? t1 : t2
        os += -hopping, "Cdag", j, "C", j + 1
        os += -hopping, "Cdag", j + 1, "C", j
    end

    H = MPO(os, sites)

    # Compute the ground state psi0
    state = [isodd(n) ? "1" : "0" for n in 1:N]  # Alternating filling pattern
    psi0_init = randomMPS(sites, state)
    energy_ground, psi_ground = dmrg(H, psi0_init; nsweeps, maxdim, cutoff, noise)

    # Compute entanglement entropy for a subsystem
    function entanglement_entropy(psi, site)
        psi = orthogonalize(psi, site)
        U, S, V = svd(psi[site], (linkinds(psi, site-1)..., siteinds(psi, site)...))
        SvN = 0.0
        for n = 1:dim(S, 1)
            p = S[n, n]^2
            if p > 0
                SvN -= p * log(p)
            end
        end
        return SvN
    end

    return psi_ground, entanglement_entropy
end

# Parameters
N = 2000         # Number of sites
h = 4.0
weight = 2 
noise = [1E-10]
delta_t = 0.0  # Set delta_t to zero
nsweeps = 5      # Number of DMRG sweeps
maxdim = [20, 40, 50, 100, 200] 
cutoff = [1E-10] 

# Compute entanglement entropy for delta t = 0
t1 = 1.00 + delta_t
t2 = 1.00 - delta_t
psi_ground, entanglement_entropy = run_dmrg_ssh(N, t1, t2, nsweeps, maxdim, cutoff)
l_values = [l for l in 2:2:div(N,2)] 

entropy_values = [entanglement_entropy(psi_ground, l) for l in l_values]

# Fit the function a(l) = (c/6) * log((L/pi) * sin(pi*l/L))
L = N
define_model(l, c) = (c/6) .* log.((L/pi) .* sin.(pi .* l ./ L))

fit = curve_fit(define_model, l_values, entropy_values, [1.0])
c_value = fit.param[1]
println("Value of c for delta_t = 0: ", c_value)

# Plot EE vs l
plot(l_values, entropy_values, xlabel="l", ylabel="EE", title="EE vs l for N=2000 sites ", marker=:o, label="EE(l)")
savefig("EE_vs_l_delta_t_0.png")
# Out:
# After sweep 1 energy=-1263.0871302055377  maxlinkdim=4 maxerr=4.17E-11 time=2.605
# After sweep 2 energy=-1272.2415919757643  maxlinkdim=16 maxerr=6.76E-11 time=3.468
# After sweep 3 energy=-1272.7488819278753  maxlinkdim=50 maxerr=1.54E-10 time=11.838
# After sweep 4 energy=-1272.8094109965282  maxlinkdim=79 maxerr=1.00E-10 time=28.965
# After sweep 5 energy=-1272.8315895732305  maxlinkdim=119 maxerr=1.00E-10 time=30.344
# Value of c for delta_t = 0: 1.0899212774453337
# "/home/photon/Downloads/Cardy_Entropy/EE_vs_l_delta_t_0.png"

# %%
using ITensors, ITensorMPS, Plots, LsqFit

function dmrg_ssh(N::Int, t1::Float64, t2::Float64, nsweeps::Int, maxdim::Vector{Int}, cutoff::Vector{Float64})
    sites = siteinds("Fermion", N)
    os = OpSum()
    
    for j in 1:N-1
        hopping = isodd(j) ? t1 : t2
        os += -hopping, "Cdag", j, "C", j+1
        os += -hopping, "Cdag", j+1, "C", j
    end

    H = MPO(os, sites)

    state = [isodd(n) ? "1" : "0" for n in 1:N]
    psi0 = randomMPS(sites, state)



    # Run DMRG
    energy, psi = dmrg(H, psi0; nsweeps)

    # Function to compute entanglement entropy
    function entanglement_entropy(psi, site)
        psi = orthogonalize(psi, site)
        U, S, V = svd(psi[site], (linkinds(psi, site-1)..., siteinds(psi, site)...))
        SvN = 0.0
        for i = 1:dim(S, 1)
            p = S[i, i]^2
            if p > 0
                SvN -= p * log(p)
            end
        end
        return SvN
    end

    return psi, entanglement_entropy
end

# Parameters
N = 200
δt = 0.0
nsweeps = 5
maxdim = [20, 40, 50, 100, 200]
cutoff = [1E-10]

t1 = 1.0 + δt
t2 = 1.2 - δt

# Run DMRG
psi, entanglement_entropy = dmrg_ssh(N, t1, t2, nsweeps, maxdim, cutoff)

# Compute entanglement entropy values
l_values = [l for l in 2:2:div(N,2)] 

entropy_val = [entanglement_entropy(psi, l) for l in l_values]
# Define model for curve fitting
L = N
define_model(l, c) = (c/ 6) .* log.((L / π) .* sin.(π .* l ./ L))

# Fit the central charge
fit = curve_fit(define_model, l_values, entropy_val, [1.0])
c_value = fit.param[1]
println("Value of c: ", c_value)

# Plot results
plot(l_values, entropy_val, xlabel="l", ylabel="EE", label="Data")
savefig("EE_vs_l.png")
# Out:
# After sweep 1 energy=-140.54437110320782  maxlinkdim=4 maxerr=0.00E+00 time=0.139
# After sweep 2 energy=-141.2257784665416  maxlinkdim=16 maxerr=0.00E+00 time=0.180
# After sweep 3 energy=-141.23045018428496  maxlinkdim=64 maxerr=2.21E-16 time=0.818
# After sweep 4 energy=-141.23045971472578  maxlinkdim=131 maxerr=2.22E-16 time=5.320
# After sweep 5 energy=-141.23046024193968  maxlinkdim=176 maxerr=2.22E-16 time=8.422
# Value of c: 1.2439834928543088
# "/home/photon/Downloads/Cardy_Entropy/EE_vs_l.png"
